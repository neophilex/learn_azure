# %% [markdown]
# https://docs.microsoft.com/en-gb/azure/cognitive-services/form-recognizer/quickstarts/client-library?tabs=linux&pivots=programming-language-python

# %%
key = '197e883bb96542f2b33e773f92112c8a'
endpoint ='https://form-recognizerx.cognitiveservices.azure.com/'

# %%
import os
import azure.ai.formrecognizer
from azure.core.credentials import AzureKeyCredential
from azure.core.exceptions import ResourceNotFoundError

from azure.ai.formrecognizer import FormRecognizerClient
from azure.ai.formrecognizer import FormTrainingClient

form_recognizer_client = FormRecognizerClient(endpoint=endpoint, credential=AzureKeyCredential(key))
form_training_client = FormTrainingClient(endpoint, AzureKeyCredential(key))

# %%
trainingDataUrl = 'https://thestoragex.blob.core.windows.net/archieve-storage?sp=racwdl&st=2020-07-28T18:51:31Z&se=2020-07-31T18:51:00Z&sv=2019-12-12&sr=c&sig=23H4Uq9u4vS8KLYmlJTd60UDNAa9uYSqQ9e7YblJr10%3D'
formUrl = "https://raw.githubusercontent.com/Azure/azure-sdk-for-python/master/sdk/formrecognizer/azure-ai-formrecognizer/tests/sample_forms/receipt/contoso-receipt.png"
receiptUrl = "https://raw.githubusercontent.com/Azure/azure-sdk-for-python/master/sdk/formrecognizer/azure-ai-formrecognizer/tests/sample_forms/receipt/contoso-receipt.png"

# %%
poller = form_recognizer_client.begin_recognize_content_from_url(receiptUrl)
contents = poller.result()

# %%
for line in contents[0].lines:
    print(line.text, line.bounding_box)
# Out:
# Contoso [Point(x=405.0, y=273.0), Point(x=1049.0, y=273.0), Point(x=1052.0, y=403.0), Point(x=407.0, y=415.0)]
# Contoso [Point(x=327.0, y=592.0), Point(x=498.0, y=602.0), Point(x=494.0, y=655.0), Point(x=324.0, y=642.0)]
# 123 Main Street [Point(x=318.0, y=689.0), Point(x=649.0, y=692.0), Point(x=648.0, y=754.0), Point(x=317.0, y=752.0)]
# Redmond, WA 98052 [Point(x=315.0, y=794.0), Point(x=749.0, y=795.0), Point(x=748.0, y=858.0), Point(x=315.0, y=856.0)]
# 123-456-7890 [Point(x=305.0, y=1004.0), Point(x=619.0, y=1014.0), Point(x=617.0, y=1072.0), Point(x=305.0, y=1061.0)]
# 6/10/20 19 13:59 [Point(x=301.0, y=1222.0), Point(x=630.0, y=1227.0), Point(x=629.0, y=1287.0), Point(x=301.0, y=1284.0)]
# Sales Associate: Paul [Point(x=298.0, y=1335.0), Point(x=772.0, y=1339.0), Point(x=772.0, y=1396.0), Point(x=298.0, y=1393.0)]
# 1 Surface Pro 6 [Point(x=333.0, y=1558.0), Point(x=670.0, y=1562.0), Point(x=670.0, y=1625.0), Point(x=333.0, y=1622.0)]
# 256GB / Intel Core i5 / [Point(x=370.0, y=1670.0), Point(x=842.0, y=1672.0), Point(x=841.0, y=1742.0), Point(x=369.0, y=1737.0)]
# 8GB RAM (Black) [Point(x=366.0, y=1786.0), Point(x=731.0, y=1788.0), Point(x=730.0, y=1849.0), Point(x=366.0, y=1846.0)]
# $ 999.00 [Point(x=938.0, y=1788.0), Point(x=1133.0, y=1793.0), Point(x=1131.0, y=1860.0), Point(x=939.0, y=1854.0)]
# 1 SurfacePen [Point(x=319.0, y=2018.0), Point(x=628.0, y=2014.0), Point(x=630.0, y=2077.0), Point(x=320.0, y=2083.0)]
# $ 99.99 [Point(x=965.0, y=2024.0), Point(x=1129.0, y=2027.0), Point(x=1128.0, y=2095.0), Point(x=966.0, y=2093.0)]
# Sub-Total [Point(x=471.0, y=2242.0), Point(x=697.0, y=2245.0), Point(x=697.0, y=2307.0), Point(x=471.0, y=2305.0)]
# $ 1098.99 [Point(x=924.0, y=2258.0), Point(x=1135.0, y=2255.0), Point(x=1137.0, y=2319.0), Point(x=926.0, y=2324.0)]
# Tax [Point(x=570.0, y=2356.0), Point(x=655.0, y=2358.0), Point(x=655.0, y=2415.0), Point(x=568.0, y=2414.0)]
# $ 104.40 [Point(x=943.0, y=2370.0), Point(x=1129.0, y=2366.0), Point(x=1130.0, y=2433.0), Point(x=945.0, y=2435.0)]
# Total [Point(x=549.0, y=2593.0), Point(x=666.0, y=2589.0), Point(x=669.0, y=2649.0), Point(x=548.0, y=2652.0)]
# $ 1203.39 [Point(x=915.0, y=2590.0), Point(x=1127.0, y=2613.0), Point(x=1120.0, y=2674.0), Point(x=909.0, y=2651.0)]

# %%
for i,j in enumerate(contents):
    for x, y in enumerate(j.lines):
        print(y)
# Out:
# FormLine(text=Contoso, bounding_box=[Point(x=405.0, y=273.0), Point(x=1049.0, y=273.0), Point(x=1052.0, y=403.0), Point(x=407.0, y=415.0)], words=[FormWord(text=Contoso, bounding_box=[Point(x=618.0, y=278.0), Point(x=1048.0, y=285.0), Point(x=1052.0, y=380.0), Point(x=623.0, y=400.0)], confidence=0.79, page_number=1)], page_number=1)
# FormLine(text=Contoso, bounding_box=[Point(x=327.0, y=592.0), Point(x=498.0, y=602.0), Point(x=494.0, y=655.0), Point(x=324.0, y=642.0)], words=[FormWord(text=Contoso, bounding_box=[Point(x=328.0, y=592.0), Point(x=496.0, y=604.0), Point(x=493.0, y=656.0), Point(x=324.0, y=643.0)], confidence=0.686, page_number=1)], page_number=1)
# FormLine(text=123 Main Street, bounding_box=[Point(x=318.0, y=689.0), Point(x=649.0, y=692.0), Point(x=648.0, y=754.0), Point(x=317.0, y=752.0)], words=[FormWord(text=123, bounding_box=[Point(x=321.0, y=689.0), Point(x=387.0, y=692.0), Point(x=385.0, y=753.0), Point(x=318.0, y=750.0)], confidence=0.958, page_number=1), FormWord(text=Main, bounding_box=[Point(x=399.0, y=693.0), Point(x=499.0, y=695.0), Point(x=498.0, y=754.0), Point(x=397.0, y=754.0)], confidence=0.959, page_number=1), FormWord(text=Street, bounding_box=[Point(x=511.0, y=696.0), Point(x=645.0, y=696.0), Point(x=646.0, y=751.0), Point(x=510.0, y=754.0)], confidence=0.95, page_number=1)], page_number=1)
# FormLine(text=Redmond, WA 98052, bounding_box=[Point(x=315.0, y=794.0), Point(x=749.0, y=795.0), Point(x=748.0, y=858.0), Point(x=315.0, y=856.0)], words=[FormWord(text=Redmond,, bounding_box=[Point(x=317.0, y=795.0), Point(x=523.0, y=799.0), Point(x=523.0, y=858.0), Point(x=316.0, y=855.0)], confidence=0.762, page_number=1), FormWord(text=WA, bounding_box=[Point(x=535.0, y=799.0), Point(x=598.0, y=799.0), Point(x=598.0, y=858.0), Point(x=535.0, y=858.0)], confidence=0.958, page_number=1), FormWord(text=98052, bounding_box=[Point(x=610.0, y=799.0), Point(x=745.0, y=797.0), Point(x=746.0, y=855.0), Point(x=610.0, y=858.0)], confidence=0.942, page_number=1)], page_number=1)
# FormLine(text=123-456-7890, bounding_box=[Point(x=305.0, y=1004.0), Point(x=619.0, y=1014.0), Point(x=617.0, y=1072.0), Point(x=305.0, y=1061.0)], words=[FormWord(text=123-456-7890, bounding_box=[Point(x=306.0, y=1005.0), Point(x=618.0, y=1014.0), Point(x=615.0, y=1073.0), Point(x=307.0, y=1062.0)], confidence=0.919, page_number=1)], page_number=1)
# FormLine(text=6/10/20 19 13:59, bounding_box=[Point(x=301.0, y=1222.0), Point(x=630.0, y=1227.0), Point(x=629.0, y=1287.0), Point(x=301.0, y=1284.0)], words=[FormWord(text=6/10/20, bounding_box=[Point(x=302.0, y=1222.0), Point(x=452.0, y=1225.0), Point(x=450.0, y=1287.0), Point(x=301.0, y=1285.0)], confidence=0.952, page_number=1), FormWord(text=19, bounding_box=[Point(x=464.0, y=1226.0), Point(x=505.0, y=1227.0), Point(x=504.0, y=1287.0), Point(x=463.0, y=1287.0)], confidence=0.924, page_number=1), FormWord(text=13:59, bounding_box=[Point(x=518.0, y=1227.0), Point(x=631.0, y=1230.0), Point(x=628.0, y=1287.0), Point(x=516.0, y=1287.0)], confidence=0.92, page_number=1)], page_number=1)
# FormLine(text=Sales Associate: Paul, bounding_box=[Point(x=298.0, y=1335.0), Point(x=772.0, y=1339.0), Point(x=772.0, y=1396.0), Point(x=298.0, y=1393.0)], words=[FormWord(text=Sales, bounding_box=[Point(x=302.0, y=1336.0), Point(x=418.0, y=1337.0), Point(x=417.0, y=1395.0), Point(x=300.0, y=1393.0)], confidence=0.959, page_number=1), FormWord(text=Associate:, bounding_box=[Point(x=429.0, y=1337.0), Point(x=652.0, y=1339.0), Point(x=652.0, y=1397.0), Point(x=429.0, y=1395.0)], confidence=0.9, page_number=1), FormWord(text=Paul, bounding_box=[Point(x=663.0, y=1339.0), Point(x=770.0, y=1339.0), Point(x=771.0, y=1397.0), Point(x=663.0, y=1397.0)], confidence=0.959, page_number=1)], page_number=1)
# FormLine(text=1 Surface Pro 6, bounding_box=[Point(x=333.0, y=1558.0), Point(x=670.0, y=1562.0), Point(x=670.0, y=1625.0), Point(x=333.0, y=1622.0)], words=[FormWord(text=1, bounding_box=[Point(x=334.0, y=1559.0), Point(x=361.0, y=1559.0), Point(x=360.0, y=1623.0), Point(x=333.0, y=1623.0)], confidence=0.844, page_number=1), FormWord(text=Surface, bounding_box=[Point(x=373.0, y=1560.0), Point(x=545.0, y=1563.0), Point(x=545.0, y=1625.0), Point(x=373.0, y=1624.0)], confidence=0.958, page_number=1), FormWord(text=Pro, bounding_box=[Point(x=558.0, y=1563.0), Point(x=629.0, y=1563.0), Point(x=629.0, y=1625.0), Point(x=558.0, y=1625.0)], confidence=0.884, page_number=1), FormWord(text=6, bounding_box=[Point(x=642.0, y=1564.0), Point(x=669.0, y=1564.0), Point(x=669.0, y=1624.0), Point(x=642.0, y=1625.0)], confidence=0.799, page_number=1)], page_number=1)
# FormLine(text=256GB / Intel Core i5 /, bounding_box=[Point(x=370.0, y=1670.0), Point(x=842.0, y=1672.0), Point(x=841.0, y=1742.0), Point(x=369.0, y=1737.0)], words=[FormWord(text=256GB, bounding_box=[Point(x=370.0, y=1670.0), Point(x=507.0, y=1672.0), Point(x=507.0, y=1739.0), Point(x=370.0, y=1735.0)], confidence=0.953, page_number=1), FormWord(text=/, bounding_box=[Point(x=520.0, y=1672.0), Point(x=533.0, y=1672.0), Point(x=532.0, y=1740.0), Point(x=519.0, y=1739.0)], confidence=0.841, page_number=1), FormWord(text=Intel, bounding_box=[Point(x=545.0, y=1672.0), Point(x=651.0, y=1673.0), Point(x=650.0, y=1742.0), Point(x=544.0, y=1740.0)], confidence=0.908, page_number=1), FormWord(text=Core, bounding_box=[Point(x=663.0, y=1673.0), Point(x=760.0, y=1673.0), Point(x=759.0, y=1742.0), Point(x=662.0, y=1742.0)], confidence=0.958, page_number=1), FormWord(text=i5, bounding_box=[Point(x=773.0, y=1673.0), Point(x=811.0, y=1673.0), Point(x=810.0, y=1742.0), Point(x=772.0, y=1742.0)], confidence=0.82, page_number=1)
# FormLine(text=8GB RAM (Black), bounding_box=[Point(x=366.0, y=1786.0), Point(x=731.0, y=1788.0), Point(x=730.0, y=1849.0), Point(x=366.0, y=1846.0)], words=[FormWord(text=8GB, bounding_box=[Point(x=368.0, y=1787.0), Point(x=454.0, y=1787.0), Point(x=453.0, y=1847.0), Point(x=366.0, y=1845.0)], confidence=0.908, page_number=1), FormWord(text=RAM, bounding_box=[Point(x=466.0, y=1787.0), Point(x=566.0, y=1787.0), Point(x=565.0, y=1848.0), Point(x=464.0, y=1847.0)], confidence=0.958, page_number=1), FormWord(text=(Black), bounding_box=[Point(x=577.0, y=1787.0), Point(x=729.0, y=1788.0), Point(x=728.0, y=1850.0), Point(x=576.0, y=1848.0)], confidence=0.849, page_number=1)], page_number=1)
# FormLine(text=$ 999.00, bounding_box=[Point(x=938.0, y=1788.0), Point(x=1133.0, y=1793.0), Point(x=1131.0, y=1860.0), Point(x=939.0, y=1854.0)], words=[FormWord(text=$, bounding_box=[Point(x=938.0, y=1788.0), Point(x=967.0, y=1788.0), Point(x=965.0, y=1855.0), Point(x=938.0, y=1854.0)], confidence=0.798, page_number=1), FormWord(text=999.00, bounding_box=[Point(x=980.0, y=1789.0), Point(x=1130.0, y=1793.0), Point(x=1128.0, y=1860.0), Point(x=979.0, y=1856.0)], confidence=0.909, page_number=1)], page_number=1)
# FormLine(text=1 SurfacePen, bounding_box=[Point(x=319.0, y=2018.0), Point(x=628.0, y=2014.0), Point(x=630.0, y=2077.0), Point(x=320.0, y=2083.0)], words=[FormWord(text=1, bounding_box=[Point(x=319.0, y=2018.0), Point(x=348.0, y=2018.0), Point(x=350.0, y=2084.0), Point(x=322.0, y=2084.0)], confidence=0.84, page_number=1), FormWord(text=SurfacePen, bounding_box=[Point(x=361.0, y=2018.0), Point(x=628.0, y=2014.0), Point(x=628.0, y=2076.0), Point(x=363.0, y=2083.0)], confidence=0.936, page_number=1)], page_number=1)
# FormLine(text=$ 99.99, bounding_box=[Point(x=965.0, y=2024.0), Point(x=1129.0, y=2027.0), Point(x=1128.0, y=2095.0), Point(x=966.0, y=2093.0)], words=[FormWord(text=$, bounding_box=[Point(x=965.0, y=2024.0), Point(x=995.0, y=2024.0), Point(x=994.0, y=2093.0), Point(x=965.0, y=2092.0)], confidence=0.799, page_number=1), FormWord(text=99.99, bounding_box=[Point(x=1009.0, y=2024.0), Point(x=1126.0, y=2026.0), Point(x=1125.0, y=2095.0), Point(x=1008.0, y=2093.0)], confidence=0.929, page_number=1)], page_number=1)
# FormLine(text=Sub-Total, bounding_box=[Point(x=471.0, y=2242.0), Point(x=697.0, y=2245.0), Point(x=697.0, y=2307.0), Point(x=471.0, y=2305.0)], words=[FormWord(text=Sub-Total, bounding_box=[Point(x=472.0, y=2243.0), Point(x=697.0, y=2246.0), Point(x=696.0, y=2307.0), Point(x=472.0, y=2306.0)], confidence=0.727, page_number=1)], page_number=1)
# FormLine(text=$ 1098.99, bounding_box=[Point(x=924.0, y=2258.0), Point(x=1135.0, y=2255.0), Point(x=1137.0, y=2319.0), Point(x=926.0, y=2324.0)], words=[FormWord(text=$, bounding_box=[Point(x=925.0, y=2259.0), Point(x=949.0, y=2258.0), Point(x=951.0, y=2325.0), Point(x=927.0, y=2325.0)], confidence=0.881, page_number=1), FormWord(text=1098.99, bounding_box=[Point(x=962.0, y=2258.0), Point(x=1133.0, y=2255.0), Point(x=1134.0, y=2319.0), Point(x=964.0, y=2324.0)], confidence=0.934, page_number=1)], page_number=1)
# FormLine(text=Tax, bounding_box=[Point(x=570.0, y=2356.0), Point(x=655.0, y=2358.0), Point(x=655.0, y=2415.0), Point(x=568.0, y=2414.0)], words=[FormWord(text=Tax, bounding_box=[Point(x=571.0, y=2356.0), Point(x=654.0, y=2357.0), Point(x=653.0, y=2415.0), Point(x=570.0, y=2413.0)], confidence=0.958, page_number=1)], page_number=1)
# FormLine(text=$ 104.40, bounding_box=[Point(x=943.0, y=2370.0), Point(x=1129.0, y=2366.0), Point(x=1130.0, y=2433.0), Point(x=945.0, y=2435.0)], words=[FormWord(text=$, bounding_box=[Point(x=943.0, y=2369.0), Point(x=967.0, y=2369.0), Point(x=969.0, y=2436.0), Point(x=944.0, y=2436.0)], confidence=0.894, page_number=1), FormWord(text=104.40, bounding_box=[Point(x=981.0, y=2368.0), Point(x=1126.0, y=2366.0), Point(x=1127.0, y=2433.0), Point(x=982.0, y=2435.0)], confidence=0.958, page_number=1)], page_number=1)
# FormLine(text=Total, bounding_box=[Point(x=549.0, y=2593.0), Point(x=666.0, y=2589.0), Point(x=669.0, y=2649.0), Point(x=548.0, y=2652.0)], words=[FormWord(text=Total, bounding_box=[Point(x=548.0, y=2592.0), Point(x=666.0, y=2589.0), Point(x=668.0, y=2648.0), Point(x=550.0, y=2652.0)], confidence=0.656, page_number=1)], page_number=1)
# FormLine(text=$ 1203.39, bounding_box=[Point(x=915.0, y=2590.0), Point(x=1127.0, y=2613.0), Point(x=1120.0, y=2674.0), Point(x=909.0, y=2651.0)], words=[FormWord(text=$, bounding_box=[Point(x=917.0, y=2591.0), Point(x=945.0, y=2594.0), Point(x=939.0, y=2655.0), Point(x=911.0, y=2652.0)], confidence=0.887, page_number=1), FormWord(text=1203.39, bounding_box=[Point(x=957.0, y=2595.0), Point(x=1128.0, y=2614.0), Point(x=1119.0, y=2675.0), Point(x=951.0, y=2656.0)], confidence=0.954, page_number=1)], page_number=1)

# %%
def format_bounding_box(bounding_box):
    if not bounding_box:
        return "N/A"
    return ", ".join(["[{}, {}]".format(p.x, p.y) for p in bounding_box])

# %%
for idx, content in enumerate(contents):
    print("----Recognizing content from page #{}----".format(idx))
    print("Has width: {} and height: {}, measured with unit: {}".format(
        content.width,
        content.height,
        content.unit
    ))
    for table_idx, table in enumerate(content.tables):
        print("Table # {} has {} rows and {} columns".format(table_idx, table.row_count, table.column_count))
        for cell in table.cells:
            print("...Cell[{}][{}] has text '{}'".format(
                cell.row_index,
                cell.column_index,
                cell.text,
                format_bounding_box(cell.bounding_box)
            ))
    for line_idx, line in enumerate(content.lines):
        print("Line # {} has word count '{}' and text '{}' within bounding box '{}'".format(
            line_idx,
            len(line.words),
            line.text,
            format_bounding_box(line.bounding_box)
        ))
    print("----------------------------------------")
# Out:
# ----Recognizing content from page #0----
# Has width: 1688.0 and height: 3000.0, measured with unit: pixel
# Line # 0 has word count '1' and text 'Contoso' within bounding box '[405.0, 273.0], [1049.0, 273.0], [1052.0, 403.0], [407.0, 415.0]'
# Line # 1 has word count '1' and text 'Contoso' within bounding box '[327.0, 592.0], [498.0, 602.0], [494.0, 655.0], [324.0, 642.0]'
# Line # 2 has word count '3' and text '123 Main Street' within bounding box '[318.0, 689.0], [649.0, 692.0], [648.0, 754.0], [317.0, 752.0]'
# Line # 3 has word count '3' and text 'Redmond, WA 98052' within bounding box '[315.0, 794.0], [749.0, 795.0], [748.0, 858.0], [315.0, 856.0]'
# Line # 4 has word count '1' and text '123-456-7890' within bounding box '[305.0, 1004.0], [619.0, 1014.0], [617.0, 1072.0], [305.0, 1061.0]'
# Line # 5 has word count '3' and text '6/10/20 19 13:59' within bounding box '[301.0, 1222.0], [630.0, 1227.0], [629.0, 1287.0], [301.0, 1284.0]'
# Line # 6 has word count '3' and text 'Sales Associate: Paul' within bounding box '[298.0, 1335.0], [772.0, 1339.0], [772.0, 1396.0], [298.0, 1393.0]'
# Line # 7 has word count '4' and text '1 Surface Pro 6' within bounding box '[333.0, 1558.0], [670.0, 1562.0], [670.0, 1625.0], [333.0, 1622.0]'
# Line # 8 has word count '6' and text '256GB / Intel Core i5 /' within bounding box '[370.0, 1670.0], [842.0, 1672.0], [841.0, 1742.0], [369.0, 1737.0]'
# Line # 9 has word count '3' and text '8GB RAM (Black)' within bounding box '[366.0, 1786.0], [731.0, 1788.0], [730.0, 1849.0], [366.0, 1846.0]'
# Line # 10 has word count '2' and text '$ 999.00' within bounding box '[938.0, 1788.0], [1133.0, 1793.0], [1131.0, 1860.0], [939.0, 1854.0]'
# Line # 11 has word count '2' and text '1 SurfacePen' within bounding box '[319.0, 2018.0], [628.0, 2014.0], [630.0, 2077.0], [320.0, 2083.0]'
# Line # 12 has word count '2' and text '$ 99.99' within bounding box '[965.0, 2024.0], [1129.0, 2027.0], [1128.0, 2095.0], [966.0, 2093.0]'
# Line # 13 has word count '1' and text 'Sub-Total' within bounding box '[471.0, 2242.0], [697.0, 2245.0], [697.0, 2307.0], [471.0, 2305.0]'
# Line # 14 has word count '2' and text '$ 1098.99' within bounding box '[924.0, 2258.0], [1135.0, 2255.0], [1137.0, 2319.0], [926.0, 2324.0]'
# Line # 15 has word count '1' and text 'Tax' within bounding box '[570.0, 2356.0], [655.0, 2358.0], [655.0, 2415.0], [568.0, 2414.0]'
# Line # 16 has word count '2' and text '$ 104.40' within bounding box '[943.0, 2370.0], [1129.0, 2366.0], [1130.0, 2433.0], [945.0, 2435.0]'
# Line # 17 has word count '1' and text 'Total' within bounding box '[549.0, 2593.0], [666.0, 2589.0], [669.0, 2649.0], [548.0, 2652.0]'
# Line # 18 has word count '2' and text '$ 1203.39' within bounding box '[915.0, 2590.0], [1127.0, 2613.0], [1120.0, 2674.0], [909.0, 2651.0]'
# ----------------------------------------

# %%
poller = form_recognizer_client.begin_recognize_receipts_from_url(receiptUrl)
receipts = poller.result()

# %%
receipts[0].fields
# Out:
# {'Items': FormField(label_data=None, value_data=FieldText(page_number=None, text=None, bounding_box=None, text_content=None), name=Items, value=[FormField(label_data=None, value_data=FieldText(page_number=None, text=None, bounding_box=None, text_content=None), name=Items, value={'Name': FormField(label_data=None, value_data=FieldText(page_number=1, text=8GB RAM (Black), bounding_box=[Point(x=370.7, y=1781.5), Point(x=731.0, y=1785.0), Point(x=730.3, y=1854.0), Point(x=370.0, y=1850.6)], text_content=None), name=Name, value='8GB RAM (Black)', confidence=0.916), 'TotalPrice': FormField(label_data=None, value_data=FieldText(page_number=1, text=$999.00, bounding_box=[Point(x=939.0, y=1784.6), Point(x=1134.4, y=1788.3), Point(x=1133.0, y=1863.0), Point(x=937.6, y=1859.3)], text_content=None), name=TotalPrice, value=999.0, confidence=0.559)}, confidence=1.0), FormField(label_data=None, value_data=FieldText(page_number=None, text=None, bounding_box=None, text_content=None), name=Items, value={'Name': FormField(label_data=None,
#  'MerchantAddress': FormField(label_data=None, value_data=FieldText(page_number=1, text=123 Main Street Redmond, WA 98052, bounding_box=[Point(x=319.9, y=689.9), Point(x=750.7, y=697.5), Point(x=747.8, y=865.6), Point(x=317.0, y=858.0)], text_content=None), name=MerchantAddress, value='123 Main Street Redmond, WA 98052', confidence=0.986),
#  'MerchantName': FormField(label_data=None, value_data=FieldText(page_number=1, text=Contoso Contoso, bounding_box=[Point(x=349.3, y=241.3), Point(x=1058.0, y=284.4), Point(x=1033.5, y=687.1), Point(x=324.8, y=644.0)], text_content=None), name=MerchantName, value='Contoso Contoso', confidence=0.516),
#  'MerchantPhoneNumber': FormField(label_data=None, value_data=FieldText(page_number=1, text=123-456-7890, bounding_box=[Point(x=306.0, y=1005.0), Point(x=617.0, y=1011.0), Point(x=615.9, y=1070.0), Point(x=304.9, y=1064.0)], text_content=None), name=MerchantPhoneNumber, value=None, confidence=0.99),
#  'ReceiptType': FormField(label_data=None, value_data=FieldText(page_number=None, text=None, bounding_box=None, text_content=None), name=ReceiptType, value='Itemized', confidence=0.659),
#  'Subtotal': FormField(label_data=None, value_data=FieldText(page_number=1, text=1098.99, bounding_box=[Point(x=963.0, y=2259.5), Point(x=1136.0, y=2254.0), Point(x=1138.1, y=2320.0), Point(x=965.1, y=2325.5)], text_content=None), name=Subtotal, value=1098.99, confidence=0.964),
#  'Tax': FormField(label_data=None, value_data=FieldText(page_number=1, text=$104.40, bounding_box=[Point(x=942.6, y=2367.5), Point(x=1132.0, y=2363.7), Point(x=1133.4, y=2434.2), Point(x=944.0, y=2438.0)], text_content=None), name=Tax, value=104.4, confidence=0.713),
#  'Total': FormField(label_data=None, value_data=FieldText(page_number=1, text=1203.39, bounding_box=[Point(x=955.0, y=2593.9), Point(x=1123.0, y=2611.0), Point(x=1116.2, y=2678.1), Point(x=948.2, y=2661.0)], text_content=None), name=Total, value=1203.39, confidence=0.774),
#  'TransactionDate': FormField(label_data=None, value_data=FieldText(page_number=1, text=6/10/2019, bounding_box=[Point(x=303.2, y=1223.5), Point(x=506.0, y=1224.0), Point(x=505.8, y=1289.0), Point(x=303.0, y=1288.5)], text_content=None), name=TransactionDate, value=datetime.date(2019, 6, 10), confidence=0.985),
#  'TransactionTime': FormField(label_data=None, value_data=FieldText(page_number=1, text=13:59, bounding_box=[Point(x=518.0, y=1225.0), Point(x=628.1, y=1227.0), Point(x=627.0, y=1291.0), Point(x=516.8, y=1289.0)], text_content=None), name=TransactionTime, value=datetime.time(13, 59), confidence=0.968)}

# %%
for idx, receipt in enumerate(receipts):
    print("--------Recognizing receipt #{}--------".format(idx))
    receipt_type = receipt.fields.get("ReceiptType")
    if receipt_type:
        print("Receipt Type: {} has confidence: {}".format(receipt_type.value, receipt_type.confidence))
    merchant_name = receipt.fields.get("MerchantName")
    if merchant_name:
        print("Merchant Name: {} has confidence: {}".format(merchant_name.value, merchant_name.confidence))
    transaction_date = receipt.fields.get("TransactionDate")
    if transaction_date:
        print("Transaction Date: {} has confidence: {}".format(transaction_date.value, transaction_date.confidence))
# Out:
# --------Recognizing receipt #0--------
# Receipt Type: Itemized has confidence: 0.659
# Merchant Name: Contoso Contoso has confidence: 0.516
# Transaction Date: 2019-06-10 has confidence: 0.985

# %%
print("Receipt items:")
for idx, item in enumerate(receipt.fields.get("Items").value):
    print("...Item #{}".format(idx))
    item_name = item.value.get("Name")
    if item_name:
        print("......Item Name: {} has confidence: {}".format(item_name.value, item_name.confidence))
    item_quantity = item.value.get("Quantity")
    if item_quantity:
        print("......Item Quantity: {} has confidence: {}".format(item_quantity.value, item_quantity.confidence))
    item_price = item.value.get("Price")
    if item_price:
        print("......Individual Item Price: {} has confidence: {}".format(item_price.value, item_price.confidence))
    item_total_price = item.value.get("TotalPrice")
    if item_total_price:
        print("......Total Item Price: {} has confidence: {}".format(item_total_price.value, item_total_price.confidence))
# Out:
# Receipt items:
# ...Item #0
# ......Item Name: 8GB RAM (Black) has confidence: 0.916
# ......Total Item Price: 999.0 has confidence: 0.559
# ...Item #1
# ......Item Name: SurfacePen has confidence: 0.858
# ......Item Quantity: None has confidence: 0.858
# ......Total Item Price: 99.99 has confidence: 0.386

# %%
subtotal = receipt.fields.get("Subtotal")
if subtotal:
    print("Subtotal: {} has confidence: {}".format(subtotal.value, subtotal.confidence))
tax = receipt.fields.get("Tax")
if tax:
    print("Tax: {} has confidence: {}".format(tax.value, tax.confidence))
tip = receipt.fields.get("Tip")
if tip:
    print("Tip: {} has confidence: {}".format(tip.value, tip.confidence))
total = receipt.fields.get("Total")
if total:
    print("Total: {} has confidence: {}".format(total.value, total.confidence))
print("--------------------------------------")

# %%
poller = form_training_client.begin_training(trainingDataUrl, use_training_labels=False)
model = poller.result()

# %%
f = open('./test.jpg','rb').read()

# %%
f
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xe1\x00>Exif\x00\x00II*\x00\x08\x00\x00\x00\x02\x001\x01\x02\x00\x07\x00\x00\x00&\x00\x00\x00;\x01\x02\x00\t\x00\x00\x00-\x00\x00\x00\x00\x00\x00\x00Picasa\x00anna1311\x00\xff\xe1\x01\xaahttp://ns.adobe.com/xap/1.0/\x00<?xpacket begin="\xef\xbb\xbf" id="W5M0MpCehiHzreSzNTczkc9d"?> <x:xmpmeta xmlns:x="adobe:ns:meta/" x:xmptk="XMP Core 5.5.0"> <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"> <rdf:Description rdf:about="" xmlns:dc="http://purl.org/dc/elements/1.1/"> <dc:creator> <rdf:Seq> <rdf:li>anna1311</rdf:li> </rdf:Seq> </dc:creator> </rdf:Description> </rdf:RDF> </x:xmpmeta>   <?xpacket end="w"?>\xff\xdb\x00\x84\x00\x03\x02\x02\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\n\x08\x08\x08\x08\n\n\t\x08\x08\x0b\r\n\x08\r\x08\x08\t\x08\x01\x03\x04\x04\x06\x05\x06\n\x06\x06\n\x10\x0e\x0b\x0e\x0f\x0f\x10\x10\x10\x0f\x10\r\x0f\x10\x10\x10\x0f\r\x0f\r\x0f\x0f\r\x0f\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\r\xff\xc0\x00\x11\x08\x02\x00\x02\x00\x03\x01\x11\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1d\x00\x00\x02\x02\x03\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x04\x03\x05\x01\x02\x06\x07\x08\t\xff\xc4\x00C\x10\x00\x02\x01\x02\x04\x04\x04\x03\x06\x05\x03\x03\x04\x02\x02\x03\x01\x02\x11\x00\x03\x04\x12!1\x05AQa\x06\x13"q\x072\x81BR\x91\xa1\xb1\xc1\x14#b\xd1\xf0\x083\xe1\x15r\xf1\x16$C\x82S\xb2\x92\xd2\x174\xc2\xff\xc4\x00\x1c\x01\x01\x00\x02\x03\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x03\x04\x02\x05\x06\x01\x07\x08\xff\xc4\x00B\x11\x00\x01\x04\x00\x04\x04\x04\x03\x07\x03\x03\x04\x02\x00\x07\x01\x01\x00\x02\x03\x11\x04\x12!1\x05AQa\x13"q\x81\x06\x91\xa1\x142B\xb1\xc1\xd1\xf0#\xe1\xf1Rbr\x15$3\x92C\x82\x16DS\xa2\xb2\xc2\xe2%\xff\xda\x00\x0c\x03\x01\x00\x02\x11\x03\x11\x00?\x00\xfdS\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2,M\x11\x13DE\x11\x13DD\xd1\x114DM\x11\x13DE\x11\x13DD\xd1\x16h\x8b\x13DY\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x88\xa2"\x88\x8a"(\x8b\x13DD\xd1\x16\x97\xaf\x05\x12H\x03\xa9 ~\xb5\x83\x9e\xd6\x8b&\x96@\x13\xb0I\xde\xe3\x089\xcf\xe1\x15U\xf8\xb8\xd8.\xc7\xcdL\xdc;\xdc\x95n?\xd0\x0frj\xbf\xdbA\xd8+\x03\x08F\xea\x1b\xbce\xc8%r\x9f\xce\xb18\xa7\x96\xdb\x00+1\x87`#5\xfeJ\x97\x86\xf8\xc6\xed\xcb\x8c\x82\xc5\xd0\xab \xdce\xc8\xa4\xff\x00H:\x9a\xd1a8\xcc\xf8\x89\x0cb\x17\x86\x8f\xc4\xe1B\xfb+\xf3p\xd8\xa1`q\x91\xa4\x9eWdz\xd2w\r\xc4\xefz\x99\xf3\x00 ...
